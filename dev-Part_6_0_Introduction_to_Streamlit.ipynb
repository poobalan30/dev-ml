# %% [markdown]
# ## About the instructor:
#
# **Dr Vijayakumar**
#
# vijaymmu@gmail.com

# %% [markdown]
# # Getting Started with Streamlit
# [Streamlit](https://streamlit.io/) turns data scripts into shareable web apps in minutes.
# All in Python. All for free. No front‑end experience required.

# %% [markdown]
# ### 1. Create a GitHub account https://github.com/
# Upload the file iris-ml-app.py
# ### 2. Install streamlit  https://streamlit.io/
# You will eventually see something like thissomething likethis
# ![streamlit.JPG](data:image/jpeg;base64,...)

# %% [markdown]
# ### 3. To deploy your application with [streamlit](https://share.streamlit.io/)
#
# Create a file called requirements.txt which contains the follwing lines<br>
# * altair
# * pandas
# * streamlit
# * sklearn
#
# You'll need to have the following files in github:
# * requirements.txt
# * yourapp.py
# * and any other files (e.g. datasets) related to your app

# %% [markdown]
# Step 1: Open a new app
# ![image.png](data:image/png;base64,...)

# %% [markdown]
# Step 2: Fill in the details OR directly paste your github repo link  ![image.png](data:image/png;base64,...)

# %% [markdown]
# Lastly ...
# ![image.png](data:image/png;base64,...)

# %% [markdown]
# ### 4. Create our first app

# %%
# %%writefile myfirstapp.py
import streamlit as st
import numpy as np
import pandas as pd

st.header("My first Streamlit App")
st.write(pd.DataFrame({
    'Intplan': ['yes', 'yes', 'yes', 'no'],
    'Churn Status': [0, 0, 0, 1]
}))
# Out:
# Overwriting myfirstapp.py

# %% [markdown]
# ### 3. Start our app!

# %% [markdown]
# # 5. Writing Own Codes

# %% [markdown]
# Now let’s get started with Streamlit with own codes.

# %% [markdown]
# # 6. Adding Interactivity
# Complete Reference: [Streamlit API](https://docs.streamlit.io/en/stable/api.html)

# %% [markdown]
# ### Checkbox

# %%
# %%writefile myfirstapp.py
import streamlit as st
import pandas as pd

st.header("My first Streamlit App")

st.write('Before you continue, please read the [terms and conditions](https://www.gnu.org/licenses/gpl-3.0.en.html)')
show = st.checkbox('I agree the terms and conditions')
if show:
    st.write(pd.DataFrame({
    'Intplan': ['yes', 'yes', 'yes', 'no'],
    'Churn Status': [0, 0, 0, 1]
}))
# Out:
# Overwriting myfirstapp.py

# %% [markdown]
# ### Select Box

# %%
# %%writefile myfirstapp.py
import streamlit as st
import numpy as np
import pandas as pd

st.header("My first Streamlit App")

option = st.sidebar.selectbox(
    'Select a mini project',
     ['line chart','map','T n C'])

if option=='line chart':
    chart_data = pd.DataFrame(
    np.random.randn(20, 3),
    columns=['a', 'b', 'c'])

    st.line_chart(chart_data)

elif option=='map':
    map_data = pd.DataFrame(
    np.random.randn(1000, 2) / [50, 50] + [37.76, -122.4],
    columns=['lat', 'lon'])

    st.map(map_data)

else:
    st.write('Before you continue, please read the [terms and conditions](https://www.gnu.org/licenses/gpl-3.0.en.html)')
    show = st.checkbox('I agree the terms and conditions')
    if show:
        st.write(pd.DataFrame({
        'Intplan': ['yes', 'yes', 'yes', 'no'],
        'Churn Status': [0, 0, 0, 1]
        }))
# Out:
# Overwriting myfirstapp.py

# %% [markdown]
# ### 7. Run Progress

# %%
# %%writefile myfirstapp.py
import streamlit as st
import numpy as np
import pandas as pd
import time

st.header("My first Streamlit App")

option = st.sidebar.selectbox(
    'Select a mini project',
     ['line chart','map','T n C','Long Process'])

if option=='line chart':
    chart_data = pd.DataFrame(
    np.random.randn(20, 3),
    columns=['a', 'b', 'c'])

    st.line_chart(chart_data)

elif option=='map':
    map_data = pd.DataFrame(
    np.random.randn(1000, 2) / [50, 50] + [37.76, -122.4],
    columns=['lat', 'lon'])

    st.map(map_data)

elif option=='T n C':
    st.write('Before you continue, please read the [terms and conditions](https://www.gnu.org/licenses/gpl-3.0.en.html)')
    show = st.checkbox('I agree the terms and conditions')
    if show:
        st.write(pd.DataFrame({
        'Intplan': ['yes', 'yes', 'yes', 'no'],
        'Churn Status': [0, 0, 0, 1]
        }))

else:
    'Starting a long computation...'
    
    latest_iteration = st.empty()
    bar = st.progress(0)

    for i in range(100):
   
        latest_iteration.text(f'Iteration {i+1}')
        bar.progress(i + 1)
        time.sleep(0.1)

    '...and now we\'re done!'
# Out:
# Overwriting myfirstapp.py

# %% [markdown]
# # 8. Exercise: Classification Model
# Load iris-ml-app.py in github and link to streamlit

# %% [markdown]
# # Exercise
# By referring to [Demo 1: Classification Model](https://github.com/dataprofessor/streamlit_freecodecamp/blob/main/app_7_classification_iris/iris-ml-app.py), modify the code for the followings:
#
# 1. Download the [IRIS.csv dataset from kaggle](https://www.kaggle.com/datasets/arshid/iris-flower-dataset), then upload it to your github repo. Get the url of the dataset by clicking "Raw".
# 2. Delete line 3
# 3. Line 31: instead of reading the iris dataset from a package, read it from your github repo.
# 4. Line 32: extract the feature columns
# 5. Line 33: extract the target column
# 6. Line 42: change "iris.target_names" to the list of the 3 species.
# 7. Comment/delete line 45 and uncomment line 46.
#
# You should get a resulting web app as shown below:

# %% [markdown]
# ![1.png](data:image/png;base64,...)

# %% [markdown]
# # Final Assignment (For Beginners)
# 1. ![2.png](data:image/png;base64,...)
# Change the above to a table, instead of a list like this.
# 2. Add image(s) or other widgets to this web app. (Hint: Refer to the [Streamlit API](https://docs.streamlit.io/en/stable/api.html))

# %% [markdown]
# # Final Assignment (Further Challenge)
# **You are encouraged to try this to get distinction** 👍
#
# Using any datasets of your choice, produce a web app that runs machine learning for data analytics.
